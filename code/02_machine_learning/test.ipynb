# %%
import pandas as pd

data = pd.read_json("../../data/imdb_top250_movies.json")

# %%
data
# Out:
#                         title                                    url duration  \
# 0    The Shawshank Redemption  https://www.imdb.com/title/tt0111161/    2H22M
# 1               The Godfather  https://www.imdb.com/title/tt0068646/    2H55M
# 2             The Dark Knight  https://www.imdb.com/title/tt0468569/    2H32M
# 3       The Godfather Part II  https://www.imdb.com/title/tt0071562/    3H22M
# 4                12 Angry Men  https://www.imdb.com/title/tt0050083/    1H36M
# ..                        ...                                    ...      ...
# 245        Gangs of Wasseypur  https://www.imdb.com/title/tt1954470/    5H21M
# 246             Into the Wild  https://www.imdb.com/title/tt0758758/    2H28M
# 247                  The Help  https://www.imdb.com/title/tt1454029/    2H26M
# 248                  Drishyam  https://www.imdb.com/title/tt4430212/    2H43M
# 249             Groundhog Day  https://www.imdb.com/title/tt0107048/    1H41M
#
# ...
